# %%
# import

import pandas as pd

from ML_lib.Services.ShowDataframeService import ShowDataframeService
from ML_lib.Services.DataframeService import DataframeService

# %%
df_train_path = 'https://raw.githubusercontent.com/dataworkshop/webinar-titanic/master/input/train.csv'
df_test_path = 'https://raw.githubusercontent.com/dataworkshop/webinar-titanic/master/input/test.csv'
titanicDataframeService = DataframeService(df_train_path)
titanicShowService = ShowDataframeService(titanicDataframeService.get_dataframe())

# %%
# Out:
# imported data:  <class 'pandas.core.frame.DataFrame'>

# %%
titanicShowService.sample()
# Out:
#      PassengerId  Survived  Pclass  \
# 185          186         0       1
# 537          538         1       1
# 375          376         1       1
# 378          379         0       3
# 102          103         0       1
# 890          891         0       3
# 453          454         1       1
# 820          821         1       1
# 863          864         0       3
# 115          116         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 185                              Rood, Mr. Hugh Roscoe    male   NaN      0
# 537                                LeRoy, Miss. Bertha  female  30.0      0
# 375              Meyer, Mrs. Edgar Joseph (Leila Saks)  female   NaN      1
# 378                                Betros, Mr. Tannous    male  20.0      0
# 102                          White, Mr. Richard Frasar    male  21.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
# ...

# %%
titanicShowService.shape()
# Out:
# (891, 12)

# %%
titanicShowService.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
